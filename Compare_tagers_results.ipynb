# %%
import pandas as pd
import xml.etree.ElementTree as ET
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-29-a79ff96f17d8> in <module>
#       1 import pandas as pd
#       2 import xml.etree.ElementTree as ET
# ----> 3 from sets import Set
#
# ModuleNotFoundError: No module named 'sets'

# %%
def getTagsDataFrame(xml_path):
    tree = ET.parse(xml_path)
    root = tree.getroot()
    df = pd.DataFrame(columns=["orth", "base", "ctag", "chunk"])
    i = 0
    for chunk in root.iter('chunk'):
        chunk_index = i
        for tok in chunk.iter('tok'):
            orth = tok.find('orth').text
            for lex in tok.iter('lex'):
                if "disamb" in lex.attrib and lex.attrib['disamb']=="1":
                    base = lex.find('base').text
                    ctag = lex.find('ctag').text
                    record = pd.DataFrame(data={"orth": [orth], "base": [base], "ctag": [ctag], "chunk": chunk_index})
                    df = pd.concat([df, record], ignore_index=True)
        i += 1
    return df

# %%
gold_df = getTagsDataFrame("dataset/PolEval/gold-task-c.xml")

# %%
clarin_df = getTagsDataFrame("clarin_task_c.xml")

# %%
incorrect = []
for ch_idx in set(gold_df["chunk"]):
    gold_ch = gold_df[gold_df["chunk"] == ch_idx]
    clarin_ch = clarin_df[clarin_df["chunk"] == ch_idx]
    if len(gold_ch) != len(clarin_df):
        print("Clarin: " + str(len(gold_ch)) + ", gold:" + str(len(clarin_ch)))
        #print(gold_ch)
        #print(clarin_ch)
    else:
        incorrect.append(dataframe_difference(gold_ch, clarin_ch))
# Out:
# Clarin: 175, gold:8
# Clarin: 8, gold:31
# Clarin: 32, gold:23
# Clarin: 22, gold:13
# Clarin: 13, gold:25
# Clarin: 19, gold:9
# Clarin: 6, gold:10
# Clarin: 9, gold:7
# Clarin: 10, gold:7
# Clarin: 7, gold:13
# Clarin: 8, gold:29
# Clarin: 13, gold:18
# Clarin: 28, gold:9
# Clarin: 163, gold:6
# Clarin: 18, gold:10
# Clarin: 9, gold:8
# Clarin: 6, gold:34
# Clarin: 11, gold:12
# Clarin: 8, gold:5
# Clarin: 34, gold:7
# Clarin: 12, gold:15
# Clarin: 5, gold:12
# Clarin: 7, gold:26
# Clarin: 15, gold:10
# Clarin: 12, gold:16
# Clarin: 26, gold:12
# Clarin: 100, gold:24
# Clarin: 9, gold:11
# Clarin: 16, gold:22
# Clarin: 12, gold:7
# Clarin: 24, gold:25
# Clarin: 11, gold:31
# Clarin: 21, gold:16
# Clarin: 7, gold:49
# Clarin: 120, gold:2
# Clarin: 25, gold:17
# Clarin: 30, gold:23
# Clarin: 16, gold:5
# Clarin: 49, gold:21
# Clarin: 140, gold:2
# Clarin: 19, gold:33
# Clarin: 23, gold:19
# Clarin: 5, gold:15
# Clarin: 22, gold:2
# Clarin: 36, gold:41
# Clarin: 19, gold:14
# ...

# %%
gold_df.to_csv("tagers_results/gold.csv")
clarin_df.to_csv("tagers_results/claring.csv")

# %%
def dataframe_difference(df1, df2, which=None):
    """Find rows which are different between two DataFrames."""
    comparison_df = df1.merge(df2,
                              indicator=True,
                              how='outer')
    if which is None:
        diff_df = comparison_df[comparison_df['_merge'] != 'both']
    else:
        diff_df = comparison_df[comparison_df['_merge'] == which]
    return diff_df
asd = pd.DataFrame(data={"col1": [1,2,3], "col2": [5,6,8]})
qwe = pd.DataFrame(data={"col1": [1,3,3], "col2": [5,6,9]})
dataframe_difference(asd, qwe)
# Out:
#    col1  col2      _merge
# 0     1     5        both
# 1     2     6   left_only
# 2     3     8   left_only
# 3     3     6  right_only
# 4     3     9  right_only
#    col1  col2      _merge
# 1     2     6   left_only
# 2     3     8   left_only
# 3     3     6  right_only
# 4     3     9  right_only
